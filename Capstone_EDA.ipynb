# %% [markdown]
# <a href="https://colab.research.google.com/github/kelseymatsik/capstone/blob/main/Capstone_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.readcsv('')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-9b5c85755852> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive/My Drive/Classes/Capstone')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     123
#     124   if ' ' in mountpoint:
# --> 125     raise ValueError('Mountpoint must not contain a space.')
#     126
# ...

# %%
path = '/content/drive/My Drive/Classes/Capstone/US_chronic_disease_2023.csv'
df = pd.read_csv(path)
# Out:
# <ipython-input-6-6f1a2584557d>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 0       2010     2010           OR          Oregon       NVSS
# 1       2019     2019           AZ         Arizona      YRBSS
# 2       2019     2019           OH            Ohio      YRBSS
# 3       2019     2019           US   United States      YRBSS
# 4       2015     2015           VI  Virgin Islands      YRBSS
#
#                     Topic                      Question  Response  \
# 0  Cardiovascular Disease  Mortality from heart failure       NaN
# 1                 Alcohol       Alcohol use among youth       NaN
# 2                 Alcohol       Alcohol use among youth       NaN
# 3                 Alcohol       Alcohol use among youth       NaN
# 4                 Alcohol       Alcohol use among youth       NaN
#
#   DataValueUnit     DataValueType  ... LocationID  TopicID QuestionID  \
# 0           NaN            Number  ...         41      CVD     CVD1_4
# ...
